# %% [markdown]
# # Outils de création d'une carte avec la création d'un parcours
# Fichier nécessaire: un fichier en format .txt contenant la liste des noms de lieux à recenser sur la carte.
#
# Les outils de recherches d'informations permettent de récupérer les emplacements de chaque lieu (coordonnées GPS), le type de lieu dans lequel il est catégorisé ainsi qu'une brève description du lieu. Un fichier sous la forme d'un tableau lisible avec Excel est créé avec les informations récoltées.
#
# La récupération des coordonnées GPS permet de retracer un parcours.
#
# La carte est enregistrée en format html.
#
# Il est possible à la fin d'ajouter, à la fin du notebook, son propre fond de carte.
#
# **Avant de lancer le notebook**:
#
# Créer un dossier sur son Google Drive intitulé "Creation-de-cartes".
# Placer dans ce dossier ce notebook, ainsi que le fichier .txt contenant la liste des lieux.

# %% [markdown]
# ## Connexion à son compte GoogleDrive:
#
# - Lancer la cellule
# - Cliquer sur le lien généré en dessous
# Copier le mot de passe dans la nouvelle fenêtre ouverte où l'accès au compte est requis et le coller en dessous de la cellule.

# %%
# !pip install geopy
# !pip install --upgrade wptools
from google.colab import drive
import folium
from geopy.geocoders import Nominatim
import pandas as pd
from folium import plugins
import json
import urllib.parse, urllib.request
import numpy as np
import csv
from collections import Counter
from branca.element import Figure

drive.mount('/content/drive/')
# %cd /content/drive/My Drive/NER-demo-lieux/
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy) (1.50)
# Requirement already up-to-date: wptools in /usr/local/lib/python3.7/dist-packages (0.4.17)
# Requirement already satisfied, skipping upgrade: lxml in /usr/local/lib/python3.7/dist-packages (from wptools) (4.2.6)
# Requirement already satisfied, skipping upgrade: certifi in /usr/local/lib/python3.7/dist-packages (from wptools) (2020.12.5)
# Requirement already satisfied, skipping upgrade: html2text in /usr/local/lib/python3.7/dist-packages (from wptools) (2020.1.16)
# Requirement already satisfied, skipping upgrade: pycurl in /usr/local/lib/python3.7/dist-packages (from wptools) (7.43.0.6)
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/NER-demo-lieux

# %% [markdown]
# ## Récupération des identifiants WIKIDATA des lieux
#
# - Indiquer le chemin du fichier .txt avec la liste des lieux (fin de la cellule)
# + possibilité de changer le nom du fichier de sortie (fichier .txt avec liste des identifiants)
# - Changer la langue si nécessaire (par défaut: français)
# - Si la détéction n'est pas assez précis, descendre "thresold" à 0.8 (moins de noms vont être identifiés), dans la cas contraire, monter le seuil à 1. Par défaut, il est placé à une valeur moyenne de 0.9

# %%
def CallWikifier(text, lang="fr", threshold=1): 
  # Thresold = taux de sureté. 0.8 = sûr que le résultat est exact; mais peu de résultat.
  # 1 = tous les résultats mais certains faux résultats
    # Url de demande:
    data = urllib.parse.urlencode([
        ("text", text), ("lang", lang),
        ("userKey", "nqvsutgqswvfmrcvyxjtopvpiukjtp"),
        ("pageRankSqThreshold", "%g" % threshold), ("applyPageRankSqThreshold", "true"),
        ("nTopDfValuesToIgnore", "200"), ("nWordsToIgnoreFromList", "200"),
        ("wikiDataClasses", "true"), ("wikiDataClassIds", "false"),
        ("support", "true"), ("ranges", "false"), ("minLinkFrequency", "4"),
        ("includeCosines", "false"), ("maxMentionEntropy", "3")
        ])
    url = "http://www.wikifier.org/annotate-article"
    # Appel de Wikifier 
    req = urllib.request.Request(url, data=data.encode("utf8"), method="POST")
    with urllib.request.urlopen(req, timeout = 100) as f:
        response = f.read()
        response = json.loads(response.decode("utf8"))
        print(response)
    # Sortie des annotations:
    with open('link-lieux2.txt', 'w') as outfile:
        for annotation in response["annotations"]:
          ## Récupération (uniquement de l'ID wikidata):
          itemid = annotation["wikiDataItemId"] 
          itemid2 = "".join([str(itemid)," "])
          outfile.write(itemid2)

with open ("test-it-lieux.txt", "r") as myfile:
    liste=myfile.read()
CallWikifier(text=liste, lang="fr")
# Out:
# {'annotations': [{'title': 'Place (voie)', 'url': 'http://fr.wikipedia.org/wiki/Place_(voie)', 'lang': 'fr', 'pageRank': 0.01030158054090963, 'secLang': 'en', 'secTitle': 'Town square', 'secUrl': 'http://en.wikipedia.org/wiki/Town_square', 'wikiDataItemId': 'Q174782', 'wikiDataClasses': [], 'dbPediaTypes': [], 'dbPediaIri': 'http://dbpedia.org/resource/Town_square', 'supportLen': 3, 'support': [{'wFrom': 0, 'wTo': 0, 'chFrom': 0, 'chTo': 4, 'pMentionGivenSurface': 0.01711017953157751, 'pageRank': 0.0004208193773132968, 'prbConfidence': 0.9652415111552961, 'entropy': 0.05889157293723925}, {'wFrom': 10, 'wTo': 10, 'chFrom': 61, 'chTo': 65, 'pMentionGivenSurface': 0.01711017953157751, 'pageRank': 0.0004208193773132968, 'prbConfidence': 0.9652415111552961, 'entropy': 0.05889157293723925}, {'wFrom': 17, 'wTo': 17, 'chFrom': 105, 'chTo': 109, 'pMentionGivenSurface': 0.01711017953157751, 'pageRank': 0.0004208193773132968, 'prbConfidence': 0.9652415111552961, 'entropy': 0.05889157293723925}]}, {'title': 'Paris', 'url': 'http://fr.wikipedia.org/wiki/Paris', 'lang': 'fr', 'pageRank': 0.03340412589754203, 'secLang': 'en', 'secTitle': 'Paris', 'secUrl': 'http://en.wikipedia.org/wiki/Paris', 'wikiDataItemId': 'Q90', 'wikiDataClasses': [{'itemId': 'Q5119', 'enLabel': 'capital'}, {'itemId': 'Q484170', 'enLabel': 'commune of France'}, {'itemId': 'Q6465', 'enLabel': 'department of France'}, {'itemId': 'Q866196', 'enLabel': 'episcopal see'}, {'itemId': 'Q1549591', 'enLabel': 'big city'}, {'itemId': 'Q208511', 'enLabel': 'global city'}, {'itemId': 'Q515', 'enLabel': 'city'}, {'itemId': 'Q1637706', 'enLabel': 'city with millions of inhabitants'}, {'itemId': 'Q486972', 'enLabel': 'human settlement'}, {'itemId': 'Q583865', 'enLabel': 'territorial collectivity of France'}, {'itemId': 'Q11618417', 'enLabel': 'LAU 2'}, {'itemId': 'Q15284', 'enLabel': 'municipality'}, {'itemId': 'Q14757767', 'enLabel': 'fourth-level administrative country subdivision'}, {'itemId': 'Q15640612', 'enLabel': 'fifth-level administrative country subdivision'}, {'itemId': 'Q3266850', 'enLabel': 'commune'}, {'itemId': 'Q192611', 'enLabel': 'constituency'}, {'itemId': 'Q13220204', 'enLabel': 'second-level administrative country subdivision'}, {'itemId': 'Q13221722', 'enLabel': 'third-level administrative country subdivision'}, {'itemId': 'Q470540', 'enLabel': 'seat'}, {'itemId': 'Q665487', 'enLabel': 'diocese'}, {'itemId': 'Q7930989', 'enLabel': 'city/town'}, {'itemId': 'Q177634', 'enLabel': 'community'}, {'itemId': 'Q702492', 'enLabel': 'urban area'}, {'itemId': 'Q82794', 'enLabel': 'geographic region'}, {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'}, {'itemId': 'Q2221906', 'enLabel': 'geographic location'}, {'itemId': 'Q192498', 'enLabel': 'administrative territorial entity of France'}, {'itemId': 'Q837766', 'enLabel': 'local authority'}, {'itemId': 'Q87712822', 'enLabel': 'moral subject of administrative law in France'}, {'itemId': 'Q163359', 'enLabel': 'local administrative unit in the NUTS system'}, {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'}, {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'}, {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'}, {'itemId': 'Q1799794', 'enLabel': 'administrative territorial entity of a specific level'}, {'itemId': 'Q467970', 'enLabel': 'permanent establishment'}, {'itemId': 'Q1492823', 'enLabel': 'ecclesiastical district'}, {'itemId': 'Q20926517', 'enLabel': 'religious administrative territorial entity'}, {'itemId': 'Q51041800', 'enLabel': 'religious administrative entity'}, {'itemId': 'Q94670589', 'enLabel': 'Christian organization'}, {'itemId': 'Q3257686', 'enLabel': 'locality'}, {'itemId': 'Q874405', 'enLabel': 'social group'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'}, {'itemId': 'Q618123', 'enLabel': 'geographical object'}, {'itemId': 'Q270 ...

# %% [markdown]
# ## Récupération des informations de chaque lieu reconnu et lié à wikidata:
#
# - Lancer la cellule
#
# Toutes les informations (le type de lieu, les coordonnées GPS (latitude et longitude) ainsi qu'une brève description du lieu) sont enregistrées et exportées sous la forme d'un fichier de données JSON ainsi que sous la forme d'un tableau dans un fichier Excel dans le Google Drive. Il est possbile de changer le nom du fichier xlsx créé à la toute dernière ligne de la cellule: ici, il se nomme "informations_lieux.xlsx"

# %%
# %cd /content/drive/My Drive/NER-demo-lieux/

import wptools
import re
import itertools

donnees ={}
nom = []
type_lieu = []
latitude = []
longitude = []
longitude = []
description = []
# Utilisation du document créé précédement avec les identifiants wikidata:
with open("/content/drive/My Drive/NER-demo-lieux/link-lieux2.txt", "r") as a_file:
      with open("donnees_lieux.json", "w") as fichier : 
        for line in a_file:
            for word in line.split():
              page = wptools.page(wikibase=word, lang="fr")
              page.get_wikidata()
              page.get_parse()
## Pour avoir toutes les informations:
              try:
                infobox=page.data['infobox']
                nom = infobox.get("nom")
                type_lieu=infobox.get("type")
                if type_lieu is None: 
                  try:
                    type_lieu=page.data['what']
                  except KeyError as ke:
                    pass
                latitude = infobox.get("latitude")
                longitude = infobox.get("longitude")
                description = page.data["description"]
              except AttributeError as at:
                print("Ce n'est pas un lieu!")
# Création d'un dictionnaire + fichier json avec les informations récupérées sur les lieux:
              try:
                donnees[nom] = {"Type de lieu" : type_lieu,
                              "Latitude" : latitude, "Longitude" : longitude, "Description": description}
              except TypeError as tpy:
                pass
      
        json.dump(donnees, fichier, ensure_ascii=False)

# Enregistrement de toutes les informations récupérées sous la forme d'un tableau Excel:
df = pd.DataFrame(donnees)
df2 = df.transpose()
df2.to_excel('informations_lieux.xlsx')
# Out:
# /content/drive/My Drive/NER-demo-lieux
# www.wikidata.org (wikidata) Q174782
# www.wikidata.org (labels) P910|P2581|P3827|P9230|P2452|Q98929991|...
# Note: Wikidata item Q174782 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:Московский Кремль №5.JPG
# Place (voie) (fr) data
# {
#   claims: <dict(29)> P508, P373, P279, P349, P646, P1051, P1709, P...
#   description: espace public non bâti, desservi par des voies
#   image: <list(1)> {'file': 'File:Московский Кремль №5.JPG', 'kind...
#   label: place
#   labels: <dict(38)> P910, P2581, P3827, P9230, P2452, Q98929991, ...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Place_(voie)
#   wikibase: Q174782
#   wikidata: <dict(27)> identifiant Bibliothèque nationale centrale...
#   wikidata_pageid: 174672
#   wikidata_url: https://www.wikidata.org/wiki/Q174782
# }
# fr.wikipedia.org (parse) Place_(voie)
# Place (voie) (fr) data
# {
#   claims: <dict(29)> P508, P373, P279, P349, P646, P1051, P1709, P...
#   description: espace public non bâti, desservi par des voies
#   image: <list(1)> {'file': 'File:Московский Кремль №5.JPG', 'kind...
#   label: place
#   labels: <dict(38)> P910, P2581, P3827, P9230, P2452, Q98929991, ...
#   modified: <dict(1)> wikidata
#   pageid: 876935
#   parsetree: <str(12726)> <root><template><title>Voir homonymes</t...
#   requests: <list(4)> wikidata, labels, imageinfo, parse
#   title: Place (voie)
#   wikibase: Q174782
#   wikidata: <dict(27)> identifiant Bibliothèque nationale centrale...
#   wikidata_pageid: 174672
#   wikidata_url: https://www.wikidata.org/wiki/Q174782
#   wikitext: <str(6896)> {{Voir homonymes|place}}[[Image:Grand_plac...
# }
# www.wikidata.org (wikidata) Q90
# Ce n'est pas un lieu!
# www.wikidata.org (labels) Q191066|Q175129|Q3252156|P41|P2950|P321...
# www.wikidata.org (labels) P3500|Q3260385|P47|Q1032646|Q3262481|Q5...
# www.wikidata.org (labels) P9037|P138|P8406|P8687|Q3485975|Q172765...
# www.wikidata.org (labels) Q158119|Q209086|P856|Q24575431|P1830|Q1...
# www.wikidata.org (labels) P1454|P3106|Q602358|Q4114391|P691|P5247...
# www.wikidata.org (labels) Q3485977|P6262|Q601266|Q386991|Q243|Q31...
# www.wikidata.org (labels) Q270230|Q208943|Q12761|P1335|Q234743|P1...
# www.wikidata.org (labels) Q64|P5785|P6200|Q640102|P982|P8422|P793...
# fr.wikipedia.org (imageinfo) File:Paris - Eiffelturm und Marsfeld2.jpg
# Paris (fr) data
# {
#   aliases: <list(5)> Ville-Lumière, Paname, Lutèce, Ville de l'Amo...
#   claims: <dict(183)> P2924, P1082, P1667, P1151, P1333, P349, P21...
#   description: capitale de la France
#   image: <list(1)> {'file': 'File:Paris - Eiffelturm und Marsfeld2...
#   label: Paris
#   labels: <dict(381)> Q191066, Q175129, Q3252156, P41, P2950, P321...
#   modified: <dict(1)> wikidata
#   requests: <list(10)> wikidata, labels, labels, labels, labels, l...
#   title: Paris
#   what: capitale
#   wikibase: Q90
#   wikidata: <dict(179)> identifiant de la Grande Encyclopédie russ...
#   wikidata_pageid: 221
#   wikidata_url: https://www.wikidata.org/wiki/Q90
# }
# fr.wikipedia.org (parse) Paris
# fr.wikipedia.org (imageinfo) File:Paris - Eiffelturm und Marsfeld2.jpg
# Paris (fr) data
# {
#   aliases: <list(5)> Ville-Lumière, Paname, Lutèce, Ville de l'Amo...
#   claims: <dict(183)> P2924, P1082, P1667, P1151, P1333, P349, P21...
#   description: capitale de la France
#   image: <list(2)> {'file': 'File:Paris - Eiffelturm und Marsfeld2...
#   infobox: <dict(29)> nom, image, légende, blason, légende blason,...
#   iwlinks: <list(5)> https://en.wikipedia.org/wiki/Environmental_R...
#   label: Paris
#   labels: <dict(381)> Q191066, Q175129, Q3252156, P41, P2950, P321...
#   modified: <dict(1)> wikidata
#   pageid: 681159
#   parsetree: <str(520852)> <root><template><title>Semi-protection ...
#   requests: <list(12)> wikidata, labels, labels, labels, labels, l...
#   title: Paris
#   what: capitale
#   wikibase: Q90
#   wikidata: <dict(179)> identifiant de la Grande Encyclopédie russ...
#   wikidata_pageid: 221
#   wikidata_url: https://www.wikidata.org/wiki/Q90
#   wikitext: <str(401805)> {{Semi-protection longue}}{{Nom protégé}...
# }
# www.wikidata.org (wikidata) Q604408
# www.wikidata.org (labels) P361|P1821|P646|P268|P138|Q3006959|Q132...
# Note: Wikidata item Q604408 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:Madeleines de Commercy.jpg
# Madeleine (pâtisserie) (fr) data
# {
#   claims: <dict(14)> P373, P646, P18, P279, P527, P495, P361, P61,...
#   description: pâtisserie
#   image: <list(1)> {'file': 'File:Madeleines de Commercy.jpg', 'ki...
#   label: madeleine
#   labels: <dict(23)> P361, P1821, P646, P268, P138, Q3006959, Q132...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Madeleine_(pâtisserie)
#   wikibase: Q604408
#   wikidata: <dict(14)> catégorie Commons (P373), identifiant Freeb...
#   wikidata_pageid: 568994
#   wikidata_url: https://www.wikidata.org/wiki/Q604408
# }
# fr.wikipedia.org (parse) Madeleine_(pâtisserie)
# fr.wikipedia.org (imageinfo) File:Madeleines de Commercy.jpg
# Madeleine (pâtisserie) (fr) data
# {
#   claims: <dict(14)> P373, P646, P18, P279, P527, P495, P361, P61,...
#   description: pâtisserie
#   image: <list(2)> {'file': 'File:Madeleines de Commercy.jpg', 'ki...
#   infobox: <dict(7)> nom, image, légende, lieu origine, créateur, ...
#   iwlinks: <list(2)> https://fr.wikibooks.org/wiki/Livre_de_cuisin...
#   label: madeleine
#   labels: <dict(23)> P361, P1821, P646, P268, P138, Q3006959, Q132...
#   modified: <dict(1)> wikidata
#   pageid: 120958
#   parsetree: <str(14457)> <root><template><title>Voir homonymes</t...
#   requests: <list(5)> wikidata, labels, imageinfo, parse, imageinfo
#   title: Madeleine (pâtisserie)
#   wikibase: Q604408
#   wikidata: <dict(14)> catégorie Commons (P373), identifiant Freeb...
#   wikidata_pageid: 568994
#   wikidata_url: https://www.wikidata.org/wiki/Q604408
#   wikitext: <str(10873)> {{Voir homonymes|Madeleine}}{{Infobox Met...
# }
# www.wikidata.org (wikidata) Q941565
# www.wikidata.org (labels) P735|P607|P20|Q1340921|P646|P2163|Q1529...
# www.wikidata.org (labels) P1343|P19|P640|P570|Q5|P1871|Q11593374
# fr.wikipedia.org (imageinfo) File:Daumesnil.jpg
# Pierre Daumesnil (fr) data
# {
#   claims: <dict(39)> P640, P21, P19, P373, P214, P166, P244, P227,...
#   description: général français
#   image: <list(1)> {'file': 'File:Daumesnil.jpg', 'kind': 'wikidat...
#   label: Pierre Daumesnil
#   labels: <dict(57)> P735, P607, P20, Q1340921, P646, P2163, Q1529...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Pierre_Daumesnil
#   what: être humain
#   wikibase: Q941565
#   wikidata: <dict(39)> identifiant Léonore (P640), sexe ou genre (...
#   wikidata_pageid: 891732
#   wikidata_url: https://www.wikidata.org/wiki/Q941565
# }
# fr.wikipedia.org (parse) Pierre_Daumesnil
# fr.wikipedia.org (imageinfo) File:Pierre Daumesnil (1776-1832).jpg
# Pierre Daumesnil (fr) data
# {
#   claims: <dict(39)> P640, P21, P19, P373, P214, P166, P244, P227,...
#   description: général français
#   image: <list(2)> {'file': 'File:Daumesnil.jpg', 'kind': 'wikidat...
#   infobox: <dict(20)> image, taille image, légende, surnom, date d...
#   iwlinks: <list(3)> https://de.wikipedia.org/wiki/Karl_von_M%C3%B...
#   label: Pierre Daumesnil
#   labels: <dict(57)> P735, P607, P20, Q1340921, P646, P2163, Q1529...
#   modified: <dict(1)> wikidata
#   pageid: 380974
#   parsetree: <str(42260)> <root><template><title>Voir homonymes</t...
#   requests: <list(6)> wikidata, labels, labels, imageinfo, parse, ...
#   title: Pierre Daumesnil
#   what: être humain
#   wikibase: Q941565
#   wikidata: <dict(39)> identifiant Léonore (P640), sexe ou genre (...
#   wikidata_pageid: 891732
#   wikidata_url: https://www.wikidata.org/wiki/Q941565
#   wikitext: <str(27705)> {{Voir homonymes|Daumesnil|Jambe de bois ...
# }
# www.wikidata.org (wikidata) Q1537246
# www.wikidata.org (labels) P361|Q50716|Q175129|P669|P646|Q5503|Q10...
# fr.wikipedia.org (imageinfo) File:Placed'ItalieMetroParis2015.JPG...
# Place d'Italie (métro de Paris) (fr) data
# {
#   aliases: <list(1)> Métro place d'Italie
#   claims: <dict(25)> P31, P81, P131, P138, P373, P197, P17, P625, ...
#   description: station du métro de Paris
#   image: <list(3)> {'file': "File:Ligne-5-Place-d'Italie-1.jpg", '...
#   label: Place d'Italie
#   labels: <dict(43)> P361, Q50716, Q175129, P669, P646, Q5503, Q10...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Place_d'Italie_(métro_de_Paris)
#   what: station de métro
#   wikibase: Q1537246
#   wikidata: <dict(25)> nature de l'élément (P31), ligne de chemin ...
#   wikidata_pageid: 1474012
#   wikidata_url: https://www.wikidata.org/wiki/Q1537246
# }
# fr.wikipedia.org (parse) Place_d'Italie_(métro_de_Paris)
# fr.wikipedia.org (imageinfo) File:EGPItalie2.JPG
# Place d'Italie (métro de Paris) (fr) data
# {
#   aliases: <list(1)> Métro place d'Italie
#   claims: <dict(25)> P31, P81, P131, P138, P373, P197, P17, P625, ...
#   description: station du métro de Paris
#   image: <list(4)> {'file': "File:Ligne-5-Place-d'Italie-1.jpg", '...
#   infobox: <dict(32)> nom, image, légende, pays, ville, titre quar...
#   label: Place d'Italie
#   labels: <dict(43)> P361, Q50716, Q175129, P669, P646, Q5503, Q10...
#   modified: <dict(1)> wikidata
#   pageid: 344650
#   parsetree: <str(23278)> <root><template><title>voir homonymes</t...
#   requests: <list(5)> wikidata, labels, imageinfo, parse, imageinfo
#   title: Place d'Italie (métro de Paris)
#   what: station de métro
#   wikibase: Q1537246
#   wikidata: <dict(25)> nature de l'élément (P31), ligne de chemin ...
#   wikidata_pageid: 1474012
#   wikidata_url: https://www.wikidata.org/wiki/Q1537246
#   wikitext: <str(15934)> {{voir homonymes|Place d'Italie}}{{Infobo...
# }
# www.wikidata.org (wikidata) Q38
# www.wikidata.org (labels) P6849|Q375619|Q1256|P41|P2950|Q115|P298...
# www.wikidata.org (labels) Q150|P92|Q822|P8744|Q125761|Q2851732|P7...
# www.wikidata.org (labels) Q132551|P214|P1792|Q676555|Q225|P299|Q1...
# www.wikidata.org (labels) Q5611262|P2250|P3911|Q1460|Q217|P3417|P...
# www.wikidata.org (labels) P1448|P1343|P1791|P6766|Q33441|P5063|Q2...
# www.wikidata.org (labels) Q7184|P901|Q884|Q1145414|Q15|Q865|Q2119...
# www.wikidata.org (labels) P5247|P6|Q190868|P3916|P242|Q1282|Q30|Q...
# www.wikidata.org (labels) Q233|Q191|Q20|Q189946|Q1273|P3175|Q9063...
# www.wikidata.org (labels) Q15085|Q7817|P3067|Q1238|P902|Q3624078|...
# www.wikidata.org (labels) P1225|Q17495|Q170424|Q35348|Q183|P2979|...
# www.wikidata.org (labels) Q3919890|P1451|P3896|Q1992919|Q7809|Q17...
# www.wikidata.org (labels) P487|Q79|P2596|P244|Q46|Q1230|Q219|P129...
# Italie (fr) data
# {
#   aliases: <list(8)> République Italienne, Italia, IT, ITA, la Rép...
#   claims: <dict(223)> P3529, P2924, P1082, P1667, P1151, P1333, P5...
#   description: État d'Europe du Sud
#   label: Italie
#   labels: <dict(562)> P6849, Q375619, Q1256, P41, P2950, Q115, P29...
#   modified: <dict(1)> wikidata
#   requests: <list(13)> wikidata, labels, labels, labels, labels, l...
#   title: Italie
#   what: État souverain
#   wikibase: Q38
#   wikidata: <dict(217)> revenu médian (P3529), identifiant de la G...
#   wikidata_pageid: 152
#   wikidata_url: https://www.wikidata.org/wiki/Q38
# }
# fr.wikipedia.org (parse) Italie
# Italie (fr) data
# {
#   aliases: <list(8)> République Italienne, Italia, IT, ITA, la Rép...
#   claims: <dict(223)> P3529, P2924, P1082, P1667, P1151, P1333, P5...
#   description: État d'Europe du Sud
#   infobox: <dict(84)> nom_français, nom_local1, langue1, image_dra...
#   iwlinks: <list(5)> https://en.wikipedia.org/wiki/Atlantic_Treaty...
#   label: Italie
#   labels: <dict(562)> P6849, Q375619, Q1256, P41, P2950, Q115, P29...
#   modified: <dict(1)> wikidata
#   pageid: 1492
#   parsetree: <str(178623)> <root><template><title>Semi-protection ...
#   requests: <list(14)> wikidata, labels, labels, labels, labels, l...
#   title: Italie
#   what: État souverain
#   wikibase: Q38
#   wikidata: <dict(217)> revenu médian (P3529), identifiant de la G...
#   wikidata_pageid: 152
#   wikidata_url: https://www.wikidata.org/wiki/Q38
#   wikitext: <str(131721)> {{Semi-protection longue}}{{Voir homonym...
# }
# www.wikidata.org (wikidata) Q79007
# www.wikidata.org (labels) P910|P361|Q6151021|P2581|P3827|P2452|Q3...
# Note: Wikidata item Q79007 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:Tweng strasse street.jpg
# Rue (fr) data
# {
#   aliases: <list(1)> voie
#   claims: <dict(30)> P279, P373, P910, P646, P1051, P1014, P1709, ...
#   description: <str(72)> voie de circulation bordée de bâtiments e...
#   image: <list(1)> {'file': 'File:Tweng strasse street.jpg', 'kind...
#   label: rue
#   labels: <dict(41)> P910, P361, Q6151021, P2581, P3827, P2452, Q3...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Rue
#   wikibase: Q79007
#   wikidata: <dict(29)> sous-classe de (P279), catégorie Commons (P...
#   wikidata_pageid: 81556
#   wikidata_url: https://www.wikidata.org/wiki/Q79007
# }
# fr.wikipedia.org (parse) Rue
# Rue (fr) data
# {
#   aliases: <list(1)> voie
#   claims: <dict(30)> P279, P373, P910, P646, P1051, P1014, P1709, ...
#   description: <str(72)> voie de circulation bordée de bâtiments e...
#   image: <list(1)> {'file': 'File:Tweng strasse street.jpg', 'kind...
#   label: rue
#   labels: <dict(41)> P910, P361, Q6151021, P2581, P3827, P2452, Q3...
#   modified: <dict(1)> wikidata
#   pageid: 131474
#   parsetree: <str(20841)> <root><template><title>voir homonymes</t...
#   requests: <list(4)> wikidata, labels, imageinfo, parse
#   title: Rue
#   wikibase: Q79007
#   wikidata: <dict(29)> sous-classe de (P279), catégorie Commons (P...
#   wikidata_pageid: 81556
#   wikidata_url: https://www.wikidata.org/wiki/Q79007
#   wikitext: <str(17159)> {{voir homonymes}}{{À internationaliser|d...
# }
# www.wikidata.org (wikidata) Q1572168
# Ce n'est pas un lieu!
# www.wikidata.org (labels) P1417|P3827|P8408|P646|P7749|P8491|P373...
# Note: Wikidata item Q1572168 missing 'instance of' (P31)
# Moulinet (pêche) (fr) data
# {
#   aliases: <list(1)> moulinet de pêche
#   claims: <dict(9)> P373, P646, P3827, P1417, P5844, P279, P8408, ...
#   label: moulinet
#   labels: <dict(11)> P1417, P3827, P8408, P646, P7749, P8491, P373...
#   modified: <dict(1)> wikidata
#   requests: <list(2)> wikidata, labels
#   title: Moulinet_(pêche)
#   wikibase: Q1572168
#   wikidata: <dict(9)> catégorie Commons (P373), identifiant Freeba...
#   wikidata_pageid: 1508106
#   wikidata_url: https://www.wikidata.org/wiki/Q1572168
# }
# fr.wikipedia.org (parse) Moulinet_(pêche)
# Moulinet (pêche) (fr) data
# {
#   aliases: <list(1)> moulinet de pêche
#   claims: <dict(9)> P373, P646, P3827, P1417, P5844, P279, P8408, ...
#   label: moulinet
#   labels: <dict(11)> P1417, P3827, P8408, P646, P7749, P8491, P373...
#   modified: <dict(1)> wikidata
#   pageid: 1039612
#   parsetree: <str(5126)> <root><template><title>Voir homonymes</ti...
#   requests: <list(3)> wikidata, labels, parse
#   title: Moulinet (pêche)
#   wikibase: Q1572168
#   wikidata: <dict(9)> catégorie Commons (P373), identifiant Freeba...
#   wikidata_pageid: 1508106
#   wikidata_url: https://www.wikidata.org/wiki/Q1572168
#   wikitext: <str(4562)> {{Voir homonymes|Moulinet}}{{ébauche|loisi...
# }
# www.wikidata.org (wikidata) Q83437773
# Ce n'est pas un lieu!
# www.wikidata.org (labels) Q175129|P669|P646|P3222|P127|Q3447125|Q...
# fr.wikipedia.org (imageinfo) File:Manufacture des Gobelins.jpg
# Manufacture des Gobelins (fr) data
# {
#   claims: <dict(20)> P31, P646, P380, P131, P669, P17, P18, P1435,...
#   description: bâtiment dans le 13e arrondissement de Paris
#   image: <list(1)> {'file': 'File:Manufacture des Gobelins.jpg', '...
#   label: manufacture des Gobelins
#   labels: <dict(31)> Q175129, P669, P646, P3222, P127, Q3447125, Q...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Manufacture_des_Gobelins
#   what: bâtiment historique
#   wikibase: Q83437773
#   wikidata: <dict(20)> nature de l'élément (P31), identifiant Free...
#   wikidata_pageid: 82754512
#   wikidata_url: https://www.wikidata.org/wiki/Q83437773
# }
# fr.wikipedia.org (parse) Manufacture_des_Gobelins
# Manufacture des Gobelins (fr) data
# {
#   claims: <dict(20)> P31, P646, P380, P131, P669, P17, P18, P1435,...
#   description: bâtiment dans le 13e arrondissement de Paris
#   image: <list(1)> {'file': 'File:Manufacture des Gobelins.jpg', '...
#   infobox: <dict(2)> boxes, count
#   iwlinks: <list(2)> https://www.wikidata.org/wiki/Q732312, https:...
#   label: manufacture des Gobelins
#   labels: <dict(31)> Q175129, P669, P646, P3222, P127, Q3447125, Q...
#   modified: <dict(1)> wikidata
#   pageid: 433230
#   parsetree: <str(63668)> <root><template><title>Infobox Monument<...
#   requests: <list(4)> wikidata, labels, imageinfo, parse
#   title: Manufacture des Gobelins
#   what: bâtiment historique
#   wikibase: Q83437773
#   wikidata: <dict(20)> nature de l'élément (P31), identifiant Free...
#   wikidata_pageid: 82754512
#   wikidata_url: https://www.wikidata.org/wiki/Q83437773
#   wikitext: <str(52248)> {{Infobox Monument}}La '''manufacture des...
# }
# www.wikidata.org (wikidata) Q19675
# www.wikidata.org (labels) P910|P2847|Q11680199|P669|P7020|P1566|P...
# www.wikidata.org (labels) Q207694|Q23908|P213|P349|Q7468438|P1329...
# www.wikidata.org (labels) Q3044767|P1619|P3025|P1005|Q141747|P856...
# www.wikidata.org (labels) P281|P2900|P4808|P1953|P4146|P214|Q127|...
# fr.wikipedia.org (imageinfo) File:Louvre 2007 02 24 c.jpg
# Musée du Louvre (fr) data
# {
#   aliases: <list(1)> Louvre
#   claims: <dict(132)> P1151, P18, P31, P361, P571, P206, P1037, P1...
#   description: musée de Paris, France
#   image: <list(1)> {'file': 'File:Louvre 2007 02 24 c.jpg', 'kind'...
#   label: musée du Louvre
#   labels: <dict(183)> P910, P2847, Q11680199, P669, P7020, P1566, ...
#   modified: <dict(1)> wikidata
#   requests: <list(6)> wikidata, labels, labels, labels, labels, im...
#   title: Musée_du_Louvre
#   what: musée d'art
#   wikibase: Q19675
#   wikidata: <dict(131)> portail Wikimedia (P1151), image (P18), na...
#   wikidata_pageid: 22813
#   wikidata_url: https://www.wikidata.org/wiki/Q19675
# }
# fr.wikipedia.org (parse) Musée_du_Louvre
# fr.wikipedia.org (imageinfo) File:Louvre Museum Wikimedia Commons.jpg
# Musée du Louvre (fr) data
# {
#   aliases: <list(1)> Louvre
#   claims: <dict(132)> P1151, P18, P31, P361, P571, P206, P1037, P1...
#   description: musée de Paris, France
#   image: <list(2)> {'file': 'File:Louvre 2007 02 24 c.jpg', 'kind'...
#   infobox: <dict(18)> image, légende, logo, pays, région, ville, t...
#   iwlinks: <list(9)> https://en.wikipedia.org/wiki/Bernardo_Caprot...
#   label: musée du Louvre
#   labels: <dict(183)> P910, P2847, Q11680199, P669, P7020, P1566, ...
#   modified: <dict(1)> wikidata
#   pageid: 36857
#   parsetree: <str(475139)> <root><template><title>Voir homonymes</...
#   requests: <list(8)> wikidata, labels, labels, labels, labels, im...
#   title: Musée du Louvre
#   what: musée d'art
#   wikibase: Q19675
#   wikidata: <dict(131)> portail Wikimedia (P1151), image (P18), na...
#   wikidata_pageid: 22813
#   wikidata_url: https://www.wikidata.org/wiki/Q19675
#   wikitext: <str(361724)> {{Voir homonymes|Louvre}}{{Infobox Musée...
# }
# www.wikidata.org (wikidata) Q39631
# www.wikidata.org (labels) P910|P2581|P2354|P3827|P4946|P646|Q7522...
# www.wikidata.org (labels) P8654|Q11974939|P9223|Q7088035|P8519|P1...
# fr.wikipedia.org (imageinfo) File:Typhoid inoculation2.jpg|File:T...
# Médecin (fr) data
# {
#   aliases: <list(5)> doctoresse, toubib, docteur, soignant, docteu...
#   claims: <dict(53)> P373, P425, P508, P910, P349, P646, P279, P18...
#   description: <str(71)> professionnel de santé diplômé d'un docto...
#   image: <list(2)> {'file': 'File:The Doctor Luke Fildes crop.jpg'...
#   label: médecin
#   labels: <dict(65)> P910, P2581, P2354, P3827, P4946, P646, Q7522...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Médecin
#   wikibase: Q39631
#   wikidata: <dict(51)> catégorie Commons (P373), domaine d'occupat...
#   wikidata_pageid: 42019
#   wikidata_url: https://www.wikidata.org/wiki/Q39631
# }
# fr.wikipedia.org (parse) Médecin
# fr.wikipedia.org (imageinfo) File:Andrea e nino pisano, medicina,...
# Médecin (fr) data
# {
#   aliases: <list(5)> doctoresse, toubib, docteur, soignant, docteu...
#   claims: <dict(53)> P373, P425, P508, P910, P349, P646, P279, P18...
#   description: <str(71)> professionnel de santé diplômé d'un docto...
#   image: <list(3)> {'file': 'File:The Doctor Luke Fildes crop.jpg'...
#   infobox: <dict(8)> appellations, image, taille image, légende, s...
#   iwlinks: <list(5)> https://en.wikipedia.org/wiki/Worshipful_Soci...
#   label: médecin
#   labels: <dict(65)> P910, P2581, P2354, P3827, P4946, P646, Q7522...
#   modified: <dict(1)> wikidata
#   pageid: 1447941
#   parsetree: <str(25127)> <root><template><title>Voir homonymes</t...
#   requests: <list(6)> wikidata, labels, labels, imageinfo, parse, ...
#   title: Médecin
#   wikibase: Q39631
#   wikidata: <dict(51)> catégorie Commons (P373), domaine d'occupat...
#   wikidata_pageid: 42019
#   wikidata_url: https://www.wikidata.org/wiki/Q39631
#   wikitext: <str(19458)> {{Voir homonymes|Médecin (homonymie)}}{{I...
# }
# www.wikidata.org (wikidata) Q237619
# www.wikidata.org (labels) P910|P850|P6105|P8707|P646|P5263|P6142|...
# fr.wikipedia.org (imageinfo) File:Riviergrondel.jpg
# Goujon (poisson) (fr) data
# {
#   aliases: <list(1)> Gobio gobio
#   claims: <dict(44)> P105, P141, P225, P373, P18, P171, P685, P815...
#   description: espèce de poissons
#   image: <list(1)> {'file': 'File:Riviergrondel.jpg', 'kind': 'wik...
#   label: Goujon
#   labels: <dict(49)> P910, P850, P6105, P8707, P646, P5263, P6142,...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Goujon_(poisson)
#   what: taxon
#   wikibase: Q237619
#   wikidata: <dict(43)> rang taxinomique (P105), statut de conserva...
#   wikidata_pageid: 231030
#   wikidata_url: https://www.wikidata.org/wiki/Q237619
# }
# fr.wikipedia.org (parse) Goujon_(poisson)
# Goujon (poisson) (fr) data
# {
#   aliases: <list(1)> Gobio gobio
#   claims: <dict(44)> P105, P141, P225, P373, P18, P171, P685, P815...
#   description: espèce de poissons
#   image: <list(1)> {'file': 'File:Riviergrondel.jpg', 'kind': 'wik...
#   infobox: <dict(2)> boxes, count
#   iwlinks: <list(4)> https://es.wikipedia.org/wiki/Gobio_alverniae...
#   label: Goujon
#   labels: <dict(49)> P910, P850, P6105, P8707, P646, P5263, P6142,...
#   modified: <dict(1)> wikidata
#   pageid: 3095107
#   parsetree: <str(25604)> <root><template><title>sous-titre/Taxon<...
#   requests: <list(4)> wikidata, labels, imageinfo, parse
#   title: Goujon (poisson)
#   what: taxon
#   wikibase: Q237619
#   wikidata: <dict(43)> rang taxinomique (P105), statut de conserva...
#   wikidata_pageid: 231030
#   wikidata_url: https://www.wikidata.org/wiki/Q237619
#   wikitext: <str(14311)> {{sous-titre/Taxon|ns1=Gobio gobio}}{{Voi...
# }
# www.wikidata.org (wikidata) Q1865480
# www.wikidata.org (labels) P361|P910|P607|P6058|Q2890900|P5063|Q56...
# www.wikidata.org (labels) P1245|Q673175|P8519|P1296|P227|P18|P134...
# fr.wikipedia.org (imageinfo) File:Bastille Exterior 1790 or 1791.jpg
# Bastille (fr) data
# {
#   aliases: <list(1)> Bastille Saint-Antoine
#   claims: <dict(41)> P373, P625, P131, P17, P646, P227, P31, P793,...
#   description: ancienne forteresse parisienne
#   image: <list(1)> {'file': 'File:Bastille Exterior 1790 or 1791.j...
#   label: Bastille
#   labels: <dict(65)> P361, P910, P607, P6058, Q2890900, P5063, Q56...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Bastille
#   what: château fort
#   wikibase: Q1865480
#   wikidata: <dict(41)> catégorie Commons (P373), coordonnées géogr...
#   wikidata_pageid: 1795830
#   wikidata_url: https://www.wikidata.org/wiki/Q1865480
# }
# fr.wikipedia.org (parse) Bastille
# fr.wikipedia.org (imageinfo) File:Bastille Exterior 1790 or 1791.jpg
# Bastille (fr) data
# {
#   aliases: <list(1)> Bastille Saint-Antoine
#   claims: <dict(41)> P373, P625, P131, P17, P646, P227, P31, P793,...
#   description: ancienne forteresse parisienne
#   image: <list(2)> {'file': 'File:Bastille Exterior 1790 or 1791.j...
#   infobox: <dict(12)> nom, image, légende, ville, pays, commune, l...
#   iwlinks: <list(3)> https://fr.wikisource.org/wiki/Dictionnaire_u...
#   label: Bastille
#   labels: <dict(65)> P361, P910, P607, P6058, Q2890900, P5063, Q56...
#   modified: <dict(1)> wikidata
#   pageid: 76907
#   parsetree: <str(62039)> <root><template><title>Voir homonymes</t...
#   requests: <list(6)> wikidata, labels, labels, imageinfo, parse, ...
#   title: Bastille
#   what: château fort
#   wikibase: Q1865480
#   wikidata: <dict(41)> catégorie Commons (P373), coordonnées géogr...
#   wikidata_pageid: 1795830
#   wikidata_url: https://www.wikidata.org/wiki/Q1865480
#   wikitext: <str(49489)> {{Voir homonymes|Bastille (homonymie)}}{{...
# }
# www.wikidata.org (wikidata) Q22746
# www.wikidata.org (labels) P910|P2581|P3827|P646|Q22698|P8520|Q294...
# Note: Wikidata item Q22746 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:Lago del rosedal palermo chico.jpg
# Jardin public (fr) data
# {
#   aliases: <list(1)> parc urbain
#   claims: <dict(16)> P279, P373, P18, P910, P3417, P227, P3827, P4...
#   description: <str(74)> terrain paysagé et planté destiné à la pr...
#   image: <list(1)> {'file': 'File:Lago del rosedal palermo chico.j...
#   label: jardin public
#   labels: <dict(20)> P910, P2581, P3827, P646, Q22698, P8520, Q294...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Jardin_public
#   wikibase: Q22746
#   wikidata: <dict(15)> sous-classe de (P279), catégorie Commons (P...
#   wikidata_pageid: 26141
#   wikidata_url: https://www.wikidata.org/wiki/Q22746
# }
# fr.wikipedia.org (parse) Jardin_public
# Jardin public (fr) data
# {
#   aliases: <list(1)> parc urbain
#   claims: <dict(16)> P279, P373, P18, P910, P3417, P227, P3827, P4...
#   description: <str(74)> terrain paysagé et planté destiné à la pr...
#   image: <list(1)> {'file': 'File:Lago del rosedal palermo chico.j...
#   iwlinks: <list(4)> https://en.wikipedia.org/wiki/Greek_gardens, ...
#   label: jardin public
#   labels: <dict(20)> P910, P2581, P3827, P646, Q22698, P8520, Q294...
#   modified: <dict(1)> wikidata
#   pageid: 230764
#   parsetree: <str(25736)> <root><template><title>Internationaliser...
#   requests: <list(4)> wikidata, labels, imageinfo, parse
#   title: Jardin public
#   wikibase: Q22746
#   wikidata: <dict(15)> sous-classe de (P279), catégorie Commons (P...
#   wikidata_pageid: 26141
#   wikidata_url: https://www.wikidata.org/wiki/Q22746
#   wikitext: <str(21204)> {{Internationaliser|date=février 2008}}[[...
# }
# www.wikidata.org (wikidata) Q8486
# Ce n'est pas un lieu!
# www.wikidata.org (labels) Q147538|P910|P2581|P3827|Q6492500|Q115|...
# www.wikidata.org (labels) P935|P7818|P373|P1417|Q37756327|P6623|Q...
# Note: Wikidata item Q8486 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:A small cup of coffee.JPG
# Café (fr) data
# {
#   claims: <dict(62)> P948, P373, P508, P910, P349, P646, P227, P93...
#   description: boisson
#   image: <list(1)> {'file': 'File:A small cup of coffee.JPG', 'kin...
#   label: café
#   labels: <dict(79)> Q147538, P910, P2581, P3827, Q6492500, Q115, ...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Café
#   wikibase: Q8486
#   wikidata: <dict(59)> bannière Wikivoyage (P948), catégorie Commo...
#   wikidata_pageid: 9792
#   wikidata_url: https://www.wikidata.org/wiki/Q8486
# }
# fr.wikipedia.org (parse) Café
# fr.wikipedia.org (imageinfo) File:A small cup of coffee.JPG
# Café (fr) data
# {
#   claims: <dict(62)> P948, P373, P508, P910, P349, P646, P227, P93...
#   description: boisson
#   image: <list(2)> {'file': 'File:A small cup of coffee.JPG', 'kin...
#   infobox: <dict(10)> nom, image, légende, pays, ville d'origine, ...
#   iwlinks: <list(8)> https://en.wikipedia.org/wiki/Black_Ivory_Cof...
#   label: café
#   labels: <dict(79)> Q147538, P910, P2581, P3827, Q6492500, Q115, ...
#   modified: <dict(1)> wikidata
#   pageid: 1885978
#   parsetree: <str(169089)> <root><template><title>Voir homonymes</...
#   requests: <list(6)> wikidata, labels, labels, imageinfo, parse, ...
#   title: Café
#   wikibase: Q8486
#   wikidata: <dict(59)> bannière Wikivoyage (P948), catégorie Commo...
#   wikidata_pageid: 9792
#   wikidata_url: https://www.wikidata.org/wiki/Q8486
#   wikitext: <str(132986)> {{Voir homonymes|café (homonymie)|kawa}}...
# }
# www.wikidata.org (wikidata) Q49845
# www.wikidata.org (labels) P910|P2581|Q7590|P3827|P989|P646|P2184|...
# Note: Wikidata item Q49845 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:USMailbox1909.jpg|File:Pillarbo...
# Poste (fr) data
# {
#   claims: <dict(28)> P508, P349, P1796, P18, P948, P910, P1807, P1...
#   description: <str(68)> système (ou entreprises) pour transporter...
#   image: <list(4)> {'file': 'File:Mailboxes.jpg', 'kind': 'wikidat...
#   label: poste
#   labels: <dict(38)> P910, P2581, Q7590, P3827, P989, P646, P2184,...
#   modified: <dict(1)> wikidata
#   requests: <list(3)> wikidata, labels, imageinfo
#   title: Poste
#   wikibase: Q49845
#   wikidata: <dict(25)> identifiant Bibliothèque nationale centrale...
#   wikidata_pageid: 51895
#   wikidata_url: https://www.wikidata.org/wiki/Q49845
# }
# fr.wikipedia.org (parse) Poste
# Poste (fr) data
# {
#   claims: <dict(28)> P508, P349, P1796, P18, P948, P910, P1807, P1...
#   description: <str(68)> système (ou entreprises) pour transporter...
#   image: <list(4)> {'file': 'File:Mailboxes.jpg', 'kind': 'wikidat...
#   label: poste
#   labels: <dict(38)> P910, P2581, Q7590, P3827, P989, P646, P2184,...
#   modified: <dict(1)> wikidata
#   pageid: 67459
#   parsetree: <str(45045)> <root><template><title>Homonyme</title><...
#   requests: <list(4)> wikidata, labels, imageinfo, parse
#   title: Poste
#   wikibase: Q49845
#   wikidata: <dict(25)> identifiant Bibliothèque nationale centrale...
#   wikidata_pageid: 51895
#   wikidata_url: https://www.wikidata.org/wiki/Q49845
#   wikitext: <str(35638)> {{Homonyme|Poste (homonymie)}}[[File:Post...
# }
# www.wikidata.org (wikidata) Q193819
# Ce n'est pas un lieu!
# www.wikidata.org (labels) P910|P4672|P1566|P41|Q193899|P6671|P785...
# www.wikidata.org (labels) Q668437|P94|P268|P1889|P5573|P4212|P856...
# fr.wikipedia.org (imageinfo) File:Château de Vincennes Paris FRA ...
# Vincennes (fr) data
# {
#   claims: <dict(59)> P1036, P190, P910, P373, P374, P17, P94, P625...
#   description: commune française du département du Val-de-Marne
#   image: <list(1)> {'file': 'File:Château de Vincennes Paris FRA 0...
#   label: Vincennes
#   labels: <dict(86)> P910, P4672, P1566, P41, Q193899, P6671, P785...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Vincennes
#   what: commune de France
#   wikibase: Q193819
#   wikidata: <dict(57)> classification décimale de Dewey (P1036), j...
#   wikidata_pageid: 191794
#   wikidata_url: https://www.wikidata.org/wiki/Q193819
# }
# fr.wikipedia.org (parse) Vincennes
# fr.wikipedia.org (imageinfo) File:Donjon du Château de Vincennes.jpg
# Vincennes (fr) data
# {
#   claims: <dict(59)> P1036, P190, P910, P373, P374, P17, P94, P625...
#   description: commune française du département du Val-de-Marne
#   image: <list(2)> {'file': 'File:Château de Vincennes Paris FRA 0...
#   infobox: <dict(27)> nom, image, légende, blason, légende blason,...
#   iwlinks: <list(1)> https://fr.wiktionary.org/wiki/Vincennes
#   label: Vincennes
#   labels: <dict(86)> P910, P4672, P1566, P41, Q193899, P6671, P785...
#   modified: <dict(1)> wikidata
#   pageid: 45586
#   parsetree: <str(84657)> <root><template><title>Voir homonymes</t...
#   requests: <list(6)> wikidata, labels, labels, imageinfo, parse, ...
#   title: Vincennes
#   what: commune de France
#   wikibase: Q193819
#   wikidata: <dict(57)> classification décimale de Dewey (P1036), j...
#   wikidata_pageid: 191794
#   wikidata_url: https://www.wikidata.org/wiki/Q193819
#   wikitext: <str(61836)> {{Voir homonymes|Vincennes (homonymie)}}{...
# }
# www.wikidata.org (wikidata) Q23397
# www.wikidata.org (labels) P6573|P910|P2581|P7697|P8989|P3827|P923...
# www.wikidata.org (labels) P244|P373|P3417|Q678259|P4223|P1225|Q19...
# Note: Wikidata item Q23397 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:Bariloche- Argentina2.jpg
# Lac (fr) data
# {
#   claims: <dict(59)> P1282, P279, P373, P910, P646, P1296, P18, P1...
#   description: étendue d'eau située à l'intérieur de terres
#   image: <list(1)> {'file': 'File:Bariloche- Argentina2.jpg', 'kin...
#   label: lac
#   labels: <dict(76)> P6573, P910, P2581, P7697, P8989, P3827, P923...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Lac
#   wikibase: Q23397
#   wikidata: <dict(58)> attribut ou clé OpenStreetMap (P1282), sous...
#   wikidata_pageid: 26792
#   wikidata_url: https://www.wikidata.org/wiki/Q23397
# }
# fr.wikipedia.org (parse) Lac
# Lac (fr) data
# {
#   claims: <dict(59)> P1282, P279, P373, P910, P646, P1296, P18, P1...
#   description: étendue d'eau située à l'intérieur de terres
#   image: <list(1)> {'file': 'File:Bariloche- Argentina2.jpg', 'kin...
#   iwlinks: <list(3)> https://fr.wikinews.org/wiki/Il_y_a_de_nombre...
#   label: lac
#   labels: <dict(76)> P6573, P910, P2581, P7697, P8989, P3827, P923...
#   modified: <dict(1)> wikidata
#   pageid: 5732
#   parsetree: <str(82279)> <root><template><title>Voir homonymes</t...
#   requests: <list(5)> wikidata, labels, labels, imageinfo, parse
#   title: Lac
#   wikibase: Q23397
#   wikidata: <dict(58)> attribut ou clé OpenStreetMap (P1282), sous...
#   wikidata_pageid: 26792
#   wikidata_url: https://www.wikidata.org/wiki/Q23397
#   wikitext: <str(63423)> {{Voir homonymes}}{{À recycler|thème=géog...
# }
# www.wikidata.org (wikidata) Q43501
# Ce n'est pas un lieu!
# www.wikidata.org (labels) P910|P2581|P3827|P9230|P2452|P646|P5357...
# www.wikidata.org (labels) Q2657718|P1225|P1014|P1417|Q1401536|P12...
# Note: Wikidata item Q43501 missing 'instance of' (P31)
# fr.wikipedia.org (imageinfo) File:Przewalskis horses exposition, ...
# Parc zoologique (fr) data
# {
#   aliases: <list(3)> zoo, jardin zoologique, Zoo jardin
#   claims: <dict(57)> P1282, P373, P508, P279, P910, P349, P227, P6...
#   description: espace où sont réunies de nombreuses espèces animales
#   image: <list(1)> {'file': 'File:Przewalskis horses exposition, Z...
#   label: parc zoologique
#   labels: <dict(68)> P910, P2581, P3827, P9230, P2452, P646, P5357...
#   modified: <dict(1)> wikidata
#   requests: <list(4)> wikidata, labels, labels, imageinfo
#   title: Parc_zoologique
#   wikibase: Q43501
#   wikidata: <dict(56)> attribut ou clé OpenStreetMap (P1282), caté...
#   wikidata_pageid: 45694
#   wikidata_url: https://www.wikidata.org/wiki/Q43501
# }
# fr.wikipedia.org (parse) Parc_zoologique
# Ce n'est pas un lieu!
# Parc zoologique (fr) data
# {
#   aliases: <list(3)> zoo, jardin zoologique, Zoo jardin
#   claims: <dict(57)> P1282, P373, P508, P279, P910, P349, P227, P6...
#   description: espace où sont réunies de nombreuses espèces animales
#   image: <list(1)> {'file': 'File:Przewalskis horses exposition, Z...
#   iwlinks: <list(12)> https://en.wikipedia.org/wiki/Greek_gardens,...
#   label: parc zoologique
#   labels: <dict(68)> P910, P2581, P3827, P9230, P2452, P646, P5357...
#   modified: <dict(1)> wikidata
#   pageid: 114061
#   parsetree: <str(55336)> <root><template><title>confusion</title>...
#   requests: <list(5)> wikidata, labels, labels, imageinfo, parse
#   title: Parc zoologique
#   wikibase: Q43501
#   wikidata: <dict(56)> attribut ou clé OpenStreetMap (P1282), caté...
#   wikidata_pageid: 45694
#   wikidata_url: https://www.wikidata.org/wiki/Q43501
#   wikitext: <str(45315)> {{confusion|Parc animalier}}{{Voir homony...
# }

# %% [markdown]
# ##Outils de calculs statistiques:
#
# Calcul des types de lieux détectés sur wikidata ainsi que la proportion de chaque.
#
# - Lancer la cellule.
#
# - Les résultats s'affichent en dessous : le nombre de lieux par "type" ainsi que la proportion de chaque catégorie.

# %%
# Récupération et création d'une liste avec catégories de lieux
keys = donnees[nom]["Type de lieu"]
liste_des_types = []
fichier_json = "/content/drive/My Drive/NER-demo-lieux/donnees_lieux.json"
with open(fichier_json, "r") as f :
  contenu_json = json.load(f)
  pairs = contenu_json.items()
  for key, value in pairs:
      test_types=value["Type de lieu"]
      liste_des_types.append(test_types)


def proportion_types(liste):
  c = Counter(liste)
  print("Voici le nombre de lieux, triés par chaque type:", c) ## Affiche le nombre de lieux de chaque type
  prop = [(i, c[i] / len(liste) * 100.0) for i in c]
  print("Voici la proportion de chaque type de lieux:", prop) ## Affiche la proportion de chaque type de lieux
  
proportion_types(liste_des_types)
# Out:
# Voici le nombre de lieux, triés par chaque type: Counter({'capitale': 1, None: 1, 'taxon': 1, 'station de métro': 1, 'Château fort, arsenal et prison': 1, '[[Boisson énergisante]] [[psychotrope]] [[stimulant]]e': 1, 'commune de France': 1})
# Voici la proportion de chaque type de lieux: [('capitale', 14.285714285714285), (None, 14.285714285714285), ('taxon', 14.285714285714285), ('station de métro', 14.285714285714285), ('Château fort, arsenal et prison', 14.285714285714285), ('[[Boisson énergisante]] [[psychotrope]] [[stimulant]]e', 14.285714285714285), ('commune de France', 14.285714285714285)]

# %% [markdown]
# ##Création d'une carte avec un parcours

# %%
keys_lat = donnees[nom]["Latitude"]
keys_long = donnees[nom]["Longitude"]
liste_des_lat = []
liste_des_long = []
fichier_json = "/content/drive/My Drive/NER-demo-lieux/donnees_lieux.json"
with open(fichier_json, "r") as f :
  contenu_json = json.load(f)
  pairs = contenu_json.items()
  for key, value in pairs:
      test_lat=value["Latitude"]
      liste_des_lat.append(test_lat)
      test_long=value["Longitude"]
      liste_des_long.append(test_long)

coords = []
for ju, ij in zip(liste_des_lat, liste_des_long):
  if ju is None:
    pass  
  elif ij is None:
    pass
  else:
    coords.append([float(ju), float(ij)])
print(coords) ### Crée un array de coordonnées en suppirimant les None

fig5=Figure(height=550,width=750)
m5=folium.Map(location=[48.856614, 2.3522219], zoom_start=12)
fig5.add_child(m5)

f1=folium.FeatureGroup("Parcours")
line_1=folium.vector_layers.PolyLine(coords,popup='<b>Parcours_test</b>',tooltip='Tour de France',color='blue',weight=4).add_to(f1)

f1.add_to(m5)
folium.LayerControl().add_to(m5)
m5
# Out:
# 1000
# <iframe src="about:blank" width="750" height="550"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_eed3beb0856e47ecb90405a1ba3fcf5c%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eed3beb0856e47ecb90405a1ba3fcf5c%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_eed3beb0856e47ecb90405a1ba3fcf5c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_eed3beb0856e47ecb90405a1ba3fcf5c%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B48.856614%2C%202.3522219%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_c6ede4b01b794b93a498e0912f69af3e%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22detectRetina%22%3A%20false%2C%0A%20%20%20%20%20%20%20%20%22maxNativeZoom%22%3A%2018%2C%0A%20%20%20%20%20%20%20%20%22maxZoom%22%3A%2018%2C%0A%20%20%20%20%20%20%20%20%22minZoom%22%3A%200%2C%0A%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Créer et ajouter son fond de carte
#
# Si l'on veut ajouter son PROPRE fond de carte personnalisé:
#
# - Création d’un compte sur : https://mapwarper.net/
#
# - Téléchargement du fond de carte (IIIF recommandé, avec la meilleure résolution possible)
#
# - Sur Map Warper: dans l’onglet « Upload Map » il est possible de charger le fond de carte que l’on veut utiliser, et indiquer toutes les métadonnées nécessaires.
#
# - Dans l’onglet "Rectify": il faut indiquer le plus de points identiques sur les deux cartes pour permettre la superposition du fond de carte chargé sur des données géolocalisées. Cliquer sur un point sur chaque carte, puis cliquer sur « add Control point » en dessous des cartes. Répéter l’opération le plus de fois possible pour obtenir un bon résultat. Dans l'encadré en dessous des deux fonds de carte, cliquer sur "Warp image": le fond s'ajoute. Si le résultat n'est pas satisfaisant, il possbile d'ajouter d'autres repères pour améliorer la qualité du nouveau fond de carte créé.
#
# - Se rendre dans l'onglet "Export". Dans "Map services", copier le lien entier se situant après "Tiles (Google/OSM scheme):", débutant par http et se terminant par .png
#
# - Coller ensuite le lien à la troisième ligne de la cellule suivante, à la place du lien existant, après "tiles = " en conservant bien les guillemets.

# %%
fig5=Figure(height=550,width=750)
m5=folium.Map(location=[48.856614, 2.3522219], zoom_start=12,
                 tiles="https://mapwarper.net/maps/tile/54525/{z}/{x}/{y}.png", attr="None")

keys_lat = donnees[nom]["Latitude"]
keys_long = donnees[nom]["Longitude"]
liste_des_lat = []
liste_des_long = []
fichier_json = "/content/drive/My Drive/NER-demo-lieux/donnees_lieux.json"
with open(fichier_json, "r") as f :
  contenu_json = json.load(f)
  pairs = contenu_json.items()
  for key, value in pairs:
      test_lat=value["Latitude"]
      liste_des_lat.append(test_lat)
      test_long=value["Longitude"]
      liste_des_long.append(test_long)

coords = []
for ju, ij in zip(liste_des_lat, liste_des_long):
  if ju is None:
    pass  
  elif ij is None:
    pass
  else:
    coords.append([float(ju), float(ij)])
print(coords) ### Crée un array de coordonnées en suppirimant les None

fig5.add_child(m5)

f1=folium.FeatureGroup("Parcours")
line_1=folium.vector_layers.PolyLine(coords,popup='<b>Parcours_test</b>',tooltip='Tour de France',color='blue',weight=4).add_to(f1)

f1.add_to(m5)
folium.LayerControl().add_to(m5)
m5
# Out:
# [[48.856578, 2.351828], [48.831483, 2.355692], [48.853333, 2.369167], [48.8477777778, 2.43916666667]]
# <iframe src="about:blank" width="750" height="550"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_eea3e6eac77b4c8ea1e2fc23bd2736bb%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eea3e6eac77b4c8ea1e2fc23bd2736bb%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_eea3e6eac77b4c8ea1e2fc23bd2736bb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_eea3e6eac77b4c8ea1e2fc23bd2736bb%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B48.856614%2C%202.3522219%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_a8ea04f0ba2646208d5c2dda47d7c8a8%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//mapwarper.net/maps/tile/54525/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20%22None%22%2C%0A%20%20%20%20%20%20%20%20%22detectRetina%22%3A%20false%2C%0A%20%20%20%20%20%20%20%20%22maxNativeZoom%22%3A%2018%2C%0A%20%20%20%20%20%20%20%20%22maxZoom%22%3A%2018%2C%0A%20%20%20%20%20%20%20%20%22minZoom%22%3A%200%2C%0A%20%20%20%20%20%2 ...
